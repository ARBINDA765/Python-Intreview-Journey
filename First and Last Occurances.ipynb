# %%
def FirstLast(input_list):
    a=[]
    for i,val in enumerate(input_list):
        if val==x:
            a.append(i)
    if a==[]:
        return [-1]
    return [a[0],a[-1]]

# %%
x=10
input_list=[10,10,10,10,1000]
FirstLast(input_list)
# Out:
# [0, 3]
