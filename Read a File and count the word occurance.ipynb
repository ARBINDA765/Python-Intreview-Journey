# %%
#Read a file and count the occurance of each word
import os
file_path="C:\DLF\ABC\XXXXXX\AWS Data Engineerng Services\XXXXX\S3 TO DYNAMO DB.txt"

word_count = {}
with open(file_path, 'r') as file:
        for line in file:
            words = line.split()
            for word in words:
                word = word.lower()
                if word in word_count:
                    word_count[word] += 1
                else:
                    word_count[word] = 1
    

print(word_count)
# Out:
# {'certainly!': 1, 'hereâ€™s': 2, 'an': 2, 'example': 5, 'of': 3, 'how': 2, 'you': 3, 'can': 4, 'write': 3, 'data': 7, 'from': 5, 's3': 3, 'to': 8, 'dynamodb': 7, 'using': 2, 'pyspark.': 1, 'this': 2, 'assumes': 1, 'have': 1, 'the': 1, 'necessary': 1, 'aws': 5, 'credentials': 2, 'and': 11, 'configurations': 1, 'set': 3, 'up.': 1, 'pyspark': 1, 'code': 1, 'up': 1, 'your': 5, 'spark': 2, 'session': 1, 'with': 2, 'configurations:': 1, 'python': 5, 'pyspark.sql': 1, 'import': 2, 'sparksession': 1, '=': 9, 'sparksession.builder': 1, '\\': 5, '.appname("s3todynamodb")': 1, '.config("spark.hadoop.fs.s3a.access.key",': 1, '"your_access_key")': 1, '.config("spark.hadoop.fs.s3a.secret.key",': 1, '"your_secret_key")': 1, '.config("spark.hadoop.fs.s3a.endpoint",': 1, '"s3.amazonaws.com")': 1, '.getorcreate()': 1, 'ai-generated': 4, 'code.': 4, 'review': 4, 'use': 9, 'carefully.': 4, 'more': 7, 'info': 4, 'on': 4, 'faq.': 4, 'read': 1, 's3:': 1, '#': 2, 'example:': 2, 'reading': 2, 'a': 2, 'csv': 
# ...

# %%
def count_words_in_file(file_path):
    word_count = {}
    
    with open(file_path, 'r') as file:
        for line in file:
            words = line.split()
            for word in words:
                word = word.lower()
                if word in word_count:
                    word_count[word] += 1
                else:
                    word_count[word] = 1
    
    return word_count

# Example usage
file_path = "C:\Ek Sapana\LIVE YOUR LIFE\GITHUB_STEP3\AWS Data Engineerng Services\RealTime\S3 TO DYNAMO DB.txt"
word_counts = count_words_in_file(file_path)
print(word_counts)
# Out:
# {'certainly!': 1, 'hereâ€™s': 2, 'an': 2, 'example': 5, 'of': 3, 'how': 2, 'you': 3, 'can': 4, 'write': 3, 'data': 7, 'from': 5, 's3': 3, 'to': 8, 'dynamodb': 7, 'using': 2, 'pyspark.': 1, 'this': 2, 'assumes': 1, 'have': 1, 'the': 1, 'necessary': 1, 'aws': 5, 'credentials': 2, 'and': 11, 'configurations': 1, 'set': 3, 'up.': 1, 'pyspark': 1, 'code': 1, 'up': 1, 'your': 5, 'spark': 2, 'session': 1, 'with': 2, 'configurations:': 1, 'python': 5, 'pyspark.sql': 1, 'import': 2, 'sparksession': 1, '=': 9, 'sparksession.builder': 1, '\\': 5, '.appname("s3todynamodb")': 1, '.config("spark.hadoop.fs.s3a.access.key",': 1, '"your_access_key")': 1, '.config("spark.hadoop.fs.s3a.secret.key",': 1, '"your_secret_key")': 1, '.config("spark.hadoop.fs.s3a.endpoint",': 1, '"s3.amazonaws.com")': 1, '.getorcreate()': 1, 'ai-generated': 4, 'code.': 4, 'review': 4, 'use': 9, 'carefully.': 4, 'more': 7, 'info': 4, 'on': 4, 'faq.': 4, 'read': 1, 's3:': 1, '#': 2, 'example:': 2, 'reading': 2, 'a': 2, 'csv': 
# ...
